# %% [markdown]
# # 📦 Detecção de Objetos com YOLOv5 Tradicional
#
# Este notebook aplica o modelo pré-treinado `yolov5s.pt` em uma imagem armazenada no Google Drive.
#
# ---

# %%
# Etapa 1: Clonar o repositório do YOLOv5 e instalar dependências
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17410, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 17410 (delta 63), reused 22 (delta 22), pack-reused 17326 (from 3)
# Receiving objects: 100% (17410/17410), 16.30 MiB | 23.64 MiB/s, done.
# Resolving deltas: 100% (11934/11934), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.9 MB/s eta 0:00:00
# ...

# %%
# Etapa 2: Montar o Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Etapa 3: Definir o caminho da imagem do Drive
caminho_imagem = '/content/drive/MyDrive/FIAP/dataset/test/bicicleta/bike.png'

# Visualizar a imagem original
from IPython.display import Image as ShowImage
ShowImage(filename=caminho_imagem)

# %%
# Etapa 4: Detectar objetos com o YOLOv5 tradicional (pré-treinado em COCO)
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source {caminho_imagem}
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/FIAP/dataset/test/bicicleta/bike.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.12 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/FIAP/dataset/test/bicicleta/bike.png: 640x640 1 bicycle, 389.0ms
# Speed: 2.6ms pre-process, 389.0ms inference, 5.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# Etapa 5: Visualizar o resultado salvo
# Atenção: O YOLO cria pastas como runs/detect/exp, exp2 etc. Verifique o nome certo abaixo.
from IPython.display import Image
Image(filename='runs/detect/exp2/bike.png')  # Edite se necessário para exp2, exp3, etc.
